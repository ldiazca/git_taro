# %% [markdown]
# <a href="https://colab.research.google.com/github/ldiazca/git_taro/blob/main/BERT_Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lautaro Díaz Campos
# ## Clasificación de reseñas clínicas con BERT multilingüe

# %%
# 1. Instalación de librerías necesarias
# !pip install transformers torch  -q

# %%
# 2. Importación de librerías
from transformers import pipeline
import pandas as pd

# %%
# 3. Creación del dataset
reseñas = [
    "La atención fue excelente, resolvieron mis dudas y el tratamiento fue efectivo.",
    "Me sentí ignorado por el personal médico, no volvería al centro.",
    "El doctor fue muy amable y profesional, me explicó todo con detalle.",
    "La espera fue demasiado larga, más de dos horas sin información.",
    "Recibí un diagnóstico claro y el tratamiento funcionó de inmediato.",
    "El personal de recepción fue grosero y no me ayudó con mis documentos.",
    "Excelente experiencia, volvería sin dudarlo.",
    "No me dieron la medicación correcta, tuve que volver al hospital.",
    "Me sentí acompañado y seguro durante todo el tratamiento.",
    "El lugar estaba sucio y sin medidas de higiene adecuadas."
]

df = pd.DataFrame({"reseña": reseñas})
df
# Out:
#                                               reseña
# 0  La atención fue excelente, resolvieron mis dud...
# 1  Me sentí ignorado por el personal médico, no v...
# 2  El doctor fue muy amable y profesional, me exp...
# 3  La espera fue demasiado larga, más de dos hora...
# 4  Recibí un diagnóstico claro y el tratamiento f...
# 5  El personal de recepción fue grosero y no me a...
# 6       Excelente experiencia, volvería sin dudarlo.
# 7  No me dieron la medicación correcta, tuve que ...
# 8  Me sentí acompañado y seguro durante todo el t...
# 9  El lugar estaba sucio y sin medidas de higiene...

# %%
# 4. Carga del modelo BERT multilingüe
modelo = "nlptown/bert-base-multilingual-uncased-sentiment"
analizador = pipeline("sentiment-analysis", model=modelo)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
# 5. Clasificación de reseñas
resultados = [analizador(texto)[0] for texto in reseñas]
df_resultados = pd.DataFrame(resultados)
df_final = pd.concat([df, df_resultados], axis=1)
df_final
# Out:
#                                               reseña    label     score
# 0  La atención fue excelente, resolvieron mis dud...  5 stars  0.543935
# 1  Me sentí ignorado por el personal médico, no v...  2 stars  0.468186
# 2  El doctor fue muy amable y profesional, me exp...  5 stars  0.683403
# 3  La espera fue demasiado larga, más de dos hora...  2 stars  0.516538
# 4  Recibí un diagnóstico claro y el tratamiento f...  4 stars  0.511703
# 5  El personal de recepción fue grosero y no me a...  2 stars  0.502128
# 6       Excelente experiencia, volvería sin dudarlo.  5 stars  0.742214
# 7  No me dieron la medicación correcta, tuve que ...   1 star  0.526143
# 8  Me sentí acompañado y seguro durante todo el t...  5 stars  0.483776
# 9  El lugar estaba sucio y sin medidas de higiene...  2 stars  0.495042

# %%
# 6. Impresión de los resultados
for idx, row in df_final.iterrows():
    print(f"Reseña: {row['reseña']}")
    print(f"Predicción del modelo: {row['label']} (score: {row['score']:.4f})\n")
# Out:
# Reseña: La atención fue excelente, resolvieron mis dudas y el tratamiento fue efectivo.
# Predicción del modelo: 5 stars (score: 0.5439)
#
# Reseña: Me sentí ignorado por el personal médico, no volvería al centro.
# Predicción del modelo: 2 stars (score: 0.4682)
#
# Reseña: El doctor fue muy amable y profesional, me explicó todo con detalle.
# Predicción del modelo: 5 stars (score: 0.6834)
#
# Reseña: La espera fue demasiado larga, más de dos horas sin información.
# Predicción del modelo: 2 stars (score: 0.5165)
#
# Reseña: Recibí un diagnóstico claro y el tratamiento funcionó de inmediato.
# Predicción del modelo: 4 stars (score: 0.5117)
#
# Reseña: El personal de recepción fue grosero y no me ayudó con mis documentos.
# Predicción del modelo: 2 stars (score: 0.5021)
#
# Reseña: Excelente experiencia, volvería sin dudarlo.
# Predicción del modelo: 5 stars (score: 0.7422)
#
# Reseña: No me dieron la medicación correcta, tuve que volver al hospital.
# ...

# %% [markdown]
# ## Reflexión
# - **Coincidencia con criterio humano:**
#    En este caso, mi impresión personal es bastante similar a la del modelo, solo que yo habría clasificado como 1 estrella algunos de los comentarios que el modelo le dió 2 estrellas.
# - **Limitaciones:**
#    - En este caso, su salida está restringida a 1–5 estrellas, y podría requerir mayores matices.
# - **Ventajas respecto a TF-IDF:**
#   - Captura el contexto y el significado de las palabras.
#   - No requiere preprocesamiento manual.
#   - Transfer learning directo sin necesidad de entrenar desde cero.
